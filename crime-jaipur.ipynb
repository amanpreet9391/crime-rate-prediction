# %%
import pandas as pd

# %%
dataset = pd.read_csv('data.csv')

# %%
dataset.head()
# Out:
#              Areas  Theft  Murder  Rape  Extortion  Avg Age of Criminals  \
# 0     ADARSH NAGAR      1       1     1          1                    22
# 1    JAWAHAR NAGAR      5       2     3          2                    23
# 2  TRANSPORT NAGAR      4       4     1          1                    25
# 3            BASSI      0       0     0          5                    26
# 4           KANOTA      3       3     3          1                    28
#
#    Cases resolve  Total crime rate
# 0              3                 4
# 1             10                12
# 2              6                13
# 3              1                 5
# 4              5                11

# %%
dataset
# Out:
#               Areas  Theft  Murder  Rape  Extortion  Avg Age of Criminals  \
# 0      ADARSH NAGAR      1       1     1          1                    22
# 1     JAWAHAR NAGAR      5       2     3          2                    23
# 2   TRANSPORT NAGAR      4       4     1          1                    25
# 3             BASSI      0       0     0          5                    26
# 4            KANOTA      3       3     3          1                    28
# 5    KHOH-NAGORIYAN      1       1     1          5                    22
# 6            TOONGA      0       0     1          1                    19
# 7      GANDHI NAGAR      1       1     1          1                    26
# 8         LAL KOTHI      1       0     0          0                    28
# 9     MOTI DOONGARI      1       2     1          1                    25
# 10      BAJAJ NAGAR      1       2     1          1                    24
# 11   JAWAHAR CIRCLE      6       1     1          1                    29
# 12    MALVIYA NAGAR      1       1     1          5                    26
# 13      PRATAPNAGAR      6       2     2          2                    22
# 14         SANGANER      1       1     1          5                    20
# 15      ASHOK NAGAR      8       4     1          1                    29
# 16       MANSAROVAR      1      25     1          1                    24
# 17    SHASTRI NAGAR      5       1     1          1                    21
# 18            CHOMU      4       4     4          8                    26
# 19          HARMARA      4       1     2          1                    56
# 20      VISHWAKARMA      7       0     0          0                    55
# 21         JHOTWARA      1      30     2          3                    54
# 22           KALWAR      1       1     0          0                    35
# 23         KARDHANI      1      12     1          3                    38
# 24       MURALIPURA      3       0     0         20                    25
# 25         BANIPARK      3       0     0          0                    45
#
#     Cases resolve  Total crime rate
# 0               3                 4
# 1              10                12
# 2               6                13
# 3               1                 5
# 4               5                11
# 5               3                11
# 6               3                 3
# 7               4                 4
# 8               1                 1
# 9               4                 5
# 10              2                 5
# 11             10                10
# 12              8                 9
# 13             11                14
# 14             11                11
# 15             12                14
# 16             20                28
# 17              9                10
# 18             18                23
# 19             12                13
# 20              6                 7
# 21             35                50
# 22              4                 4
# 23             12                16
# 24             20                26
# 25              3                 3

# %%
dataset.isnull()
# Out:
#     Areas  Theft  Murder   Rape  Extortion  Avg Age of Criminals  \
# 0   False  False   False  False      False                 False
# 1   False  False   False  False      False                 False
# 2   False  False   False  False      False                 False
# 3   False  False   False  False      False                 False
# 4   False  False   False  False      False                 False
# 5   False  False   False  False      False                 False
# 6   False  False   False  False      False                 False
# 7   False  False   False  False      False                 False
# 8   False  False   False  False      False                 False
# 9   False  False   False  False      False                 False
# 10  False  False   False  False      False                 False
# 11  False  False   False  False      False                 False
# 12  False  False   False  False      False                 False
# 13  False  False   False  False      False                 False
# 14  False  False   False  False      False                 False
# 15  False  False   False  False      False                 False
# 16  False  False   False  False      False                 False
# 17  False  False   False  False      False                 False
# 18  False  False   False  False      False                 False
# 19  False  False   False  False      False                 False
# 20  False  False   False  False      False                 False
# 21  False  False   False  False      False                 False
# 22  False  False   False  False      False                 False
# 23  False  False   False  False      False                 False
# 24  False  False   False  False      False                 False
# 25  False  False   False  False      False                 False
#
#     Cases resolve  Total crime rate
# 0           False             False
# 1           False             False
# 2           False             False
# 3           False             False
# 4           False             False
# 5           False             False
# 6           False             False
# 7           False             False
# 8           False             False
# 9           False             False
# 10          False             False
# 11          False             False
# 12          False             False
# 13          False             False
# 14          False             False
# 15          False             False
# 16          False             False
# 17          False             False
# 18          False             False
# 19          False             False
# 20          False             False
# 21          False             False
# 22          False             False
# 23          False             False
# 24          False             False
# 25          False             False

# %%
import seaborn as sns

# %%
import numpy as np

# %%
sns.heatmap(dataset.isnull())

# %%
dataset.drop(['Areas'], axis=1, inplace=True)

# %%
dataset.head()

# %%
from sklearn.model_selection import train_test_split

# %%
y = dataset.iloc[: , -1]

# %%
y
# Out:
# 0      4
# 1     12
# 2     13
# 3      5
# 4     11
# 5     11
# 6      3
# 7      4
# 8      1
# 9      5
# 10     5
# 11    10
# 12     9
# 13    14
# 14    11
# 15    14
# 16    28
# 17    10
# 18    23
# 19    13
# 20     7
# 21    50
# 22     4
# 23    16
# 24    26
# 25     3
# Name: Total crime rate, dtype: int64

# %%
X  = dataset.iloc[: , 0:7]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(X_train , y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
y_test

# %%
model.predict(X_test)
# Out:
# array([ 1., 28.,  4., 26., 10.,  5., 14., 12., 16.])

# %%
from sklearn import metrics

# %%
metrics.mean_squared_error(y_test  ,   model.predict(X_test) )
# Out:
# 3.558639194663676e-29

# %%
model.coef_
# Out:
# array([ 3.54685203e-17,  8.38549222e-17, -4.13467233e-15, -9.64417775e-17,
#         2.98589939e-16,  4.98627709e-17,  1.00000000e+00])

# %%
model.intercept_
# Out:
# -1.0658141036401503e-14
